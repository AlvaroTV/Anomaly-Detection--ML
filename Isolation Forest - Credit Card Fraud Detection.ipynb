# %% [markdown]
# ## Credit Card Fraud Detection Using Isolation Forest

# %% [markdown]
# ### Imports

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import matplotlib.gridspec as gridspec
from collections import Counter
from sklearn import metrics
import numpy as np
from matplotlib.colors import LogNorm
from sklearn.metrics import f1_score
# Out:
# /home/alvaro/snap/jupyter/common/lib/python3.7/site-packages/joblib/_multiprocessing_helpers.py:45: UserWarning: [Errno 13] Permission denied.  joblib will operate in serial mode
#   warnings.warn('%s.  joblib will operate in serial mode' % (e,))

# %%
# Jupyter Theme
from jupyterthemes import jtplot
jtplot.style(theme='gruvboxd')

# %% [markdown]
# ### 1. Reading the dataset

# %%
df = pd.read_csv("../datasets/CreditCardFraud/creditcard.csv")

# %% [markdown]
# ## 2. Information preview

# %%
df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
print("Number of features:", len(df.columns))
print("Dataset length:", len(df))
# Out:
# Number of features: 31
# Dataset length: 284807

# %%
# 492 fraudulent transactions, 284315 legitimate transactions
# The dataset is unbalanced
df["Class"].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Visualization of the types of each of the attributes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# Check if any column has null values
df.isna().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
# Graphic representation of the characteristics
features = df.drop("Class", axis=1)

plt.figure(figsize=(12,32))
gs = gridspec.GridSpec(8, 4)
gs.update(hspace=0.8)

for i, f in enumerate(features):
    ax = plt.subplot(gs[i])
    sns.histplot(df[f][df["Class"] == 1], kde=True, stat="density", linewidth=0)
    sns.histplot(df[f][df["Class"] == 0], color='orange', kde=True, stat="density", linewidth=0)
    ax.set_xlabel('')
    ax.set_title('feature: ' + str(f))

plt.show()

# %%
# Graphical representation of two features
plt.figure(figsize=(12, 6))
plt.scatter(df["V10"][df['Class'] == 0], df["V14"][df['Class'] == 0], c="g", marker=".")
plt.scatter(df["V10"][df['Class'] == 1], df["V14"][df['Class'] == 1], c="r", marker=".")
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(14,4))
gs = gridspec.GridSpec(1, 2)
# Feature 1
ax = plt.subplot(gs[0])
#sns.distplot(df["V14"][df['Class'] == 1], color='r')
sns.histplot(df["V14"][df['Class'] == 1], color="red", label="100% Equities", kde=True, stat="density", linewidth=0)
#sns.distplot(df["V14"][df['Class'] == 0], color='g')
sns.histplot(df["V14"][df['Class'] == 0], color="green", label="100% Equities", kde=True, stat="density", linewidth=0)
# Feature 2
ax = plt.subplot(gs[1])
#sns.distplot(df["V10"][df['Class'] == 1], color='r')
sns.histplot(df["V10"][df['Class'] == 1], color="red", label="100% Equities", kde=True, stat="density", linewidth=0)
#sns.distplot(df["V10"][df['Class'] == 0], color='g')
sns.histplot(df["V10"][df['Class'] == 0], color="green", label="100% Equities", kde=True, stat="density", linewidth=0)
plt.show()

# %% [markdown]
# ## 3. Dataset preparation

# %% [markdown]
# For this type of algorithm it is important that all the data is in a similar range, therefore, we can apply a scaling or normalization function.
# Another option is to eliminate features that are not in a similar range as long as they are not very influential for the prediction.

# %%
df_prep = df.drop(["Time", "Amount"], axis=1)

# %% [markdown]
# ## 4. Isolation Forest with a two-dimensional dataset

# %%
X = df_prep.drop("Class", axis=1)
y = df_prep["Class"].copy()

# %%
X_reduced = X[["V10", "V14"]].copy()

# %% [markdown]
# Training the algorithm with a reduced dataset

# %%
from sklearn.ensemble import IsolationForest

ift_clf = IsolationForest(contamination=0.01, max_samples=300)
ift_clf.fit(X_reduced)
# Out:
# IsolationForest(contamination=0.01, max_samples=300)

# %% [markdown]
# Representation of the decision limit

# %%
def plot_isolation_forest(X, y, resolution=1000):
    mins = X.min(axis=0) - 0.1
    maxs = X.max(axis=0) + 0.1
    xx, yy = np.meshgrid(np.linspace(mins[0], maxs[0], resolution),
                         np.linspace(mins[1], maxs[1], resolution))
    
    Z = ift_clf.decision_function(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z)

    plt.plot(X[:, 0][y==0], X[:, 1][y==0], 'w.')
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], 'r.')
    
plt.figure(figsize=(14, 6))
plot_isolation_forest(X_reduced.values, y)
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %% [markdown]
# Representation of identified anomalies

# %%
# Anomaly detection
anomalies = ift_clf.predict(X_reduced)

# %%
# Graphic representation of anomalies
plt.figure(figsize=(14, 6))
plt.plot(X_reduced["V10"][anomalies == -1], X_reduced["V14"][anomalies == -1], 'go', markersize=6)
plot_isolation_forest(X_reduced.values, y)
plt.xlabel("V10", fontsize=14)
plt.ylabel("V14", fontsize=14)
plt.show()

# %% [markdown]
# Prediction with the reduced dataset

# %%
print("Anomalies identified:", len(y[anomalies==-1]))
# Out:
# Anomalies identified: 2849

# %%
# True and false positives of fraudulent cases in total anomalies
y[anomalies==-1].value_counts()
# Out:
# 0    2454
# 1     395
# Name: Class, dtype: int64

# %% [markdown]
# ## 5. Isolation Fores with multidimensional dataset

# %%
# Model training
ift_clf = IsolationForest(max_samples=100, contamination=0.015)
ift_clf.fit(X)
# Out:
# IsolationForest(contamination=0.015, max_samples=100)
